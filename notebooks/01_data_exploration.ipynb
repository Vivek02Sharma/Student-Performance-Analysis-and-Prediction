# %% [markdown]
# ## Student Performance Analysis and Prediction

# %% [markdown]
# ### Performing EDA and Data visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('BMS SEM I.csv')
df.head()
# Out:
#                            CourseName  StudentId      ExamRollNumber  \
# 0  BACHELOR OF MANAGEMENT STUDIES - 1    3735942  S1/JAN22/R/ 217010
# 1  BACHELOR OF MANAGEMENT STUDIES - 1    3735958  S1/JAN22/R/ 217026
# 2  BACHELOR OF MANAGEMENT STUDIES - 1    3735997  S1/JAN22/R/ 217067
# 3  BACHELOR OF MANAGEMENT STUDIES - 1    3736013  S1/JAN22/R/ 217111
# 4  BACHELOR OF MANAGEMENT STUDIES - 1    3736069  S1/JAN22/R/ 217171
#
#                StudentName  INT_BMSBC103  EXT_BMSBC103 INT_BMSBL107  \
# 0    BORKAR  ARYA SHAILESH            35            55           31
# 1  GAIKWAD SIDDHANT SUSHIL             0             0            2
# 2       MARKAD ANIKET BALU            23            28           18
# 3   NAWALE  KALPESH  SUDAM             0            47            4
# 4     /LALWANI ANSHU GOPAL            35            45           28
#
#   EXT_BMSBL107 INT_BMSBS106 EXT_BMSBS106  ...  EXT_BMSFC104 INT_BMSFHS101  \
# ...

# %% [markdown]
# #### 1.General Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CourseName          142 non-null    object
#  1   StudentId           142 non-null    int64
#  2   ExamRollNumber      142 non-null    object
#  3   StudentName         142 non-null    object
#  4   INT_BMSBC103        142 non-null    int64
#  5   EXT_BMSBC103        142 non-null    int64
#  6   INT_BMSBL107        142 non-null    object
#  7   EXT_BMSBL107        142 non-null    object
#  8   INT_BMSBS106        142 non-null    object
#  9   EXT_BMSBS106        142 non-null    object
#  10  INT_BMSECO102       142 non-null    int64
#  11  EXT_BMSECO102       142 non-null    object
#  12  INT_BMSFA105        142 non-null    object
#  13  EXT_BMSFA105        142 non-null    int64
#  14  INT_BMSFC104        142 non-null    int64
# ...

# %%
# checking shape and size of the dataset
df.shape,df.size
# Out:
# ((142, 25), 3550)

# %%
# checking columns
df.columns
# Out:
# Index(['CourseName', 'StudentId', 'ExamRollNumber', 'StudentName',
#        'INT_BMSBC103', 'EXT_BMSBC103', 'INT_BMSBL107', 'EXT_BMSBL107',
#        'INT_BMSBS106', 'EXT_BMSBS106', 'INT_BMSECO102', 'EXT_BMSECO102',
#        'INT_BMSFA105', 'EXT_BMSFA105', 'INT_BMSFC104', 'EXT_BMSFC104',
#        'INT_BMSFHS101', 'EXT_BMSFHS101', 'Remark', 'Grade',
#        'TotalMarksObtained', 'TotalMarks', 'CreditsEarned', 'Percentage',
#        'SGPA'],
#       dtype='object')

# %%
# checking data types of each column
df.dtypes
# Out:
# CourseName             object
# StudentId               int64
# ExamRollNumber         object
# StudentName            object
# INT_BMSBC103            int64
# EXT_BMSBC103            int64
# INT_BMSBL107           object
# EXT_BMSBL107           object
# INT_BMSBS106           object
# EXT_BMSBS106           object
# INT_BMSECO102           int64
# EXT_BMSECO102          object
# INT_BMSFA105           object
# EXT_BMSFA105            int64
# INT_BMSFC104            int64
# EXT_BMSFC104            int64
# INT_BMSFHS101           int64
# EXT_BMSFHS101           int64
# Remark                 object
# Grade                  object
# TotalMarksObtained      int64
# TotalMarks              int64
# CreditsEarned           int64
# Percentage            float64
# SGPA                  float64
# dtype: object

# %%
# checking missing values
df.isnull().sum()
# Out:
# CourseName            0
# StudentId             0
# ExamRollNumber        0
# StudentName           0
# INT_BMSBC103          0
# EXT_BMSBC103          0
# INT_BMSBL107          0
# EXT_BMSBL107          0
# INT_BMSBS106          0
# EXT_BMSBS106          0
# INT_BMSECO102         0
# EXT_BMSECO102         0
# INT_BMSFA105          0
# EXT_BMSFA105          0
# INT_BMSFC104          0
# EXT_BMSFC104          0
# INT_BMSFHS101         0
# EXT_BMSFHS101         0
# Remark                0
# Grade                 0
# TotalMarksObtained    0
# TotalMarks            0
# CreditsEarned         0
# Percentage            0
# SGPA                  0
# dtype: int64

# %%
# checking the duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Conclusion** :
# - The dataset includes 142 entries with no missing values or duplicates.
# - It consists of 25 columns, including internal and external marks, total marks, and SGPA.
# - Few subjects column is object because of the grace marks ('*')
#
#
# **Note**: The problems mentioned above will be addressed during the data preprocessing step.

# %%
# importing processed data 
df = pd.read_csv(r'C:\Users\suraj\OneDrive\Desktop\Student-Performance-Analysis-and-Prediction\data\processed\BMS_process.csv')
df.head()
# Out:
#    StudentId  INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# 0    3735942            35            55            31            48
# 1    3735958             0             0             2             0
# 2    3735997            23            28            18            15
# 3    3736013             0            47             4            40
# 4    3736069            35            45            28            41
#
#    INT_BMSBS106  EXT_BMSBS106  INT_BMSECO102  EXT_BMSECO102  INT_BMSFA105  \
# 0            34            51             34             46            38
# 1             0             0             12              0             6
# 2            11            30             16             22            20
# 3             0            33              8             34             9
# 4            31            39             27             35            35
#
#    ...  EXT_BMSFC104  INT_BMSFHS101  EXT_BMSFHS101  Remark  Grade  \
# ...

# %% [markdown]
# #### 2.Descriptive Statistics

# %%
df.describe()
# Out:
#           StudentId  INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# count  1.420000e+02    142.000000    142.000000    142.000000    142.000000
# mean   3.736004e+06     30.514085     45.894366     29.528169     41.478873
# std    4.113595e+01      7.253012      7.979324      6.619007      8.733013
# min    3.735933e+06      0.000000      0.000000      2.000000      0.000000
# 25%    3.735968e+06     27.000000     44.000000     29.000000     38.000000
# 50%    3.736004e+06     31.000000     47.500000     31.000000     43.000000
# 75%    3.736039e+06     35.000000     50.000000     33.000000     46.000000
# max    3.736074e+06     40.000000     56.000000     38.000000     57.000000
#
#        INT_BMSBS106  EXT_BMSBS106  INT_BMSECO102  EXT_BMSECO102  INT_BMSFA105  \
# count    142.000000    142.000000     142.000000     142.000000    142.000000
# mean      30.633803     42.760563      30.443662      38.711268     32.915493
# ...

# %%
# checking minimum of TotalMarksObtained, CreditsEarned, Percentage, SGPA
TMO_min = df['TotalMarksObtained'].min()
CreditsEarned_min = df['CreditsEarned'].min()
Percentage_min = df['Percentage'].min()
SGPA_min = df['SGPA'].min()

print("Calcualating the minimum values of TotalMarksObtained, CreditsEarned, Percentage, SGPA")
print(f'TotalMarksObtained : {TMO_min}\nCreditsEarned : {CreditsEarned_min}\nPercentage : {Percentage_min}\nSGPA : {SGPA_min}')
# Out:
# Calcualating the minimum values of TotalMarksObtained, CreditsEarned, Percentage, SGPA
# TotalMarksObtained : 20
# CreditsEarned : 0
# Percentage : 2.86
# SGPA : 0.0

# %%
# checking average of TotalMarksObtained, CreditsEarned, Percentage, SGPA
TMO_avg = df['TotalMarksObtained'].mean()
CreditsEarned_avg = df['CreditsEarned'].mean()
Percentage_avg = df['Percentage'].mean()
SGPA_avg = df['SGPA'].mean()

print("Calcualating the average values of TotalMarksObtained, CreditsEarned, Percentage, SGPA")
print(f'TotalMarksObtained : {TMO_avg}\nCreditsEarned : {CreditsEarned_avg}\nPercentage : {Percentage_avg}\nSGPA : {SGPA_avg}')
# Out:
# Calcualating the average values of TotalMarksObtained, CreditsEarned, Percentage, SGPA
# TotalMarksObtained : 521.9859154929577
# CreditsEarned : 19.204225352112676
# Percentage : 74.56922535211268
# SGPA : 8.78943661971831

# %%
# checking maximum of TotalMarksObtained, CreditsEarned, Percentage, SGPA
TMO_max = df['TotalMarksObtained'].max()
CreditsEarned_max = df['CreditsEarned'].max()
Percentage_max = df['Percentage'].max()
SGPA_max = df['SGPA'].max()

print("Calcualating the maximum values of TotalMarksObtained, CreditsEarned, Percentage, SGPA")
print(f'TotalMarksObtained : {TMO_min}\nCreditsEarned : {CreditsEarned_max}\nPercentage : {Percentage_min}\nSGPA : {SGPA_min}')
# Out:
# Calcualating the maximum values of TotalMarksObtained, CreditsEarned, Percentage, SGPA
# TotalMarksObtained : 20
# CreditsEarned : 20
# Percentage : 2.86
# SGPA : 0.0

# %%
# frequency count of categorical columns
print("Frequency count of Remark and Grade columns\n")
print(f"Remark :\n{df['Remark'].value_counts()}\n")
print(f"Grade :\n{df['Grade'].value_counts()}")
# Out:
# Frequency count of Remark and Grade columns
#
# Remark :
# PASS    134
# FAIL      8
# Name: Remark, dtype: int64
#
# Grade :
# A+    75
# A     28
# O     19
# B+    11
# F      8
# B      1
# Name: Grade, dtype: int64

# %% [markdown]
# #### 2. Data Distribution and Visualization

# %%
# checking distribution using histogram 
plt.figure(figsize=(15,25))
for i,col in enumerate(df.drop(['StudentId','Remark','Grade','TotalMarksObtained'],axis = 1).columns,1):
        plt.subplot(10,2,i)
        sns.histplot(df[col],bins = 30,kde = True)
        plt.title(f"Histogram of {col}")
        
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    StudentId  INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# 0    3735942            35            55            31            48
# 1    3735958             0             0             2             0
# 2    3735997            23            28            18            15
# 3    3736013             0            47             4            40
# 4    3736069            35            45            28            41
#
#    INT_BMSBS106  EXT_BMSBS106  INT_BMSECO102  EXT_BMSECO102  INT_BMSFA105  \
# 0            34            51             34             46            38
# 1             0             0             12              0             6
# 2            11            30             16             22            20
# 3             0            33              8             34             9
# 4            31            39             27             35            35
#
#    ...  EXT_BMSFC104  INT_BMSFHS101  EXT_BMSFHS101  Remark  Grade  \
# ...

# %%
# checking the outliers
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.boxplot(data =df, x = df['TotalMarksObtained'])
plt.title("Boxplot of TotalMarksObtained")
plt.subplot(1,2,2)
sns.boxplot(data =df, x = df['Percentage'])
plt.title("Boxplot of Percentage")
plt.show()

# %%
# checking count of Remark and Grade columns using countplot
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.title("Count bar of Remark")
sns.countplot(x = df['Remark'],hue = df['Remark'])

plt.subplot(1,2,2)
plt.title("Count bar of Grade")
sns.countplot(x = df['Grade'],hue = df['Grade'])
plt.show()

# %%
# checking pie chart of passing and failing
remark = df['Remark'].value_counts(normalize = True)

plt.pie(remark,labels = remark.index,autopct='%1.1f%%',startangle = 100)
plt.title('Percentage of Pass and Fail')
plt.axis('equal')
plt.show()

# %%
df.head()
# Out:
#    StudentId  INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# 0    3735942            35            55            31            48
# 1    3735958             0             0             2             0
# 2    3735997            23            28            18            15
# 3    3736013             0            47             4            40
# 4    3736069            35            45            28            41
#
#    INT_BMSBS106  EXT_BMSBS106  INT_BMSECO102  EXT_BMSECO102  INT_BMSFA105  \
# 0            34            51             34             46            38
# 1             0             0             12              0             6
# 2            11            30             16             22            20
# 3             0            33              8             34             9
# 4            31            39             27             35            35
#
#    ...  EXT_BMSFC104  INT_BMSFHS101  EXT_BMSFHS101  Remark  Grade  \
# ...

# %% [markdown]
# ## Analysis Start

# %% [markdown]
# ## 1.Performance Distribution Analysis

# %%
# Total Marks Distribution
sns.histplot(df['TotalMarksObtained'],kde = True,bins = 30,color = 'cyan')
plt.title('Distribution of Total Marks obtained')
plt.xlabel('Total Marks Obtained')
plt.ylabel('Frequency')
plt.show()

# %%
# Precentage Distribution
sns.histplot(df['Percentage'],kde = True,bins = 30,color = 'salmon')
plt.title('Distribution of Percentage')
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
# SGPA Distribution
sns.histplot(df['SGPA'],kde = True,bins = 30,color = 'blue')
plt.title('Distribution of SGPA')
plt.xlabel('SGPA')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 2. Grade Analysis vs Performance

# %%
# Grade vs TotalMarksObtained
sns.boxplot(data = df,x = 'Grade',y = 'TotalMarksObtained',hue = 'Grade')
plt.title('Grade vs TotalMarksObtained')
plt.xlabel('Grade')
plt.ylabel('TotalMarksObtained')
plt.show()

# %%
# Grade vs Percentage 
sns.boxplot(data = df,x = 'Grade',y = 'Percentage',hue = 'Grade')
plt.title('Grade vs Percentage')
plt.xlabel('Grade')
plt.ylabel('Percentage')
plt.show()

# %%
sns.boxplot(data = df,x = 'Grade',y = 'SGPA',hue = 'Grade')
plt.title('Grade vs SGPA')
plt.xlabel('Grade')
plt.ylabel('SGPA')
plt.show()

# %% [markdown]
# ## 3. Remark Based Analysis

# %%
# TotalMarksObtained by Remark
sns.boxplot(data=df, x='Remark', y='TotalMarksObtained',hue = 'Remark')
plt.title('Total Marks Obtained by Remark')
plt.xlabel('Remark')
plt.ylabel('Total Marks Obtained')
plt.show()

# %%
# Percentage by Remark
sns.boxplot(data=df, x='Remark', y='Percentage', hue = 'Remark')
plt.title('Percentage by Remark')
plt.xlabel('Remark')
plt.ylabel('Percentage')
plt.show()

# %%
# SGPA by Remark
sns.boxplot(data=df, x='Remark', y='SGPA', hue = 'Remark')
plt.title('SGPA by Remark')
plt.xlabel('Remark')
plt.ylabel('SGPA')
plt.show()

# %%
# Distribution of Marks Across Grades and Remarks 
sns.scatterplot(data = df,x = 'Grade',y = 'TotalMarksObtained',hue = 'Remark')
plt.show()

# %% [markdown]
# ## 4. Course Performance Analysis

# %%
course_columns = [col for col in df.columns if col.startswith(('INT_', 'EXT_'))]
course_columns
# Out:
# ['INT_BMSBC103',
#  'EXT_BMSBC103',
#  'INT_BMSBL107',
#  'EXT_BMSBL107',
#  'INT_BMSBS106',
#  'EXT_BMSBS106',
#  'INT_BMSECO102',
#  'EXT_BMSECO102',
#  'INT_BMSFA105',
#  'EXT_BMSFA105',
#  'INT_BMSFC104',
#  'EXT_BMSFC104',
#  'INT_BMSFHS101',
#  'EXT_BMSFHS101']

# %%
# Melting DataFrame to long format
df_long = df.melt(id_vars = ['StudentId'], value_vars = course_columns, var_name = 'Course', value_name =  'Score')

plt.figure(figsize=(15, 8))
sns.boxplot(data=df_long, x='Course', y='Score',hue = 'Course')
plt.xticks(rotation=90)
plt.title('Course-wise Performance')
plt.xlabel('Course')
plt.ylabel('Score')
plt.show()

# %%
# Performance Correlation
correlation_metrics = df[course_columns].corr()
correlation_metrics
# Out:
#                INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# INT_BMSBC103       1.000000      0.593083      0.612851      0.565001
# EXT_BMSBC103       0.593083      1.000000      0.526246      0.739837
# INT_BMSBL107       0.612851      0.526246      1.000000      0.541582
# EXT_BMSBL107       0.565001      0.739837      0.541582      1.000000
# INT_BMSBS106       0.547799      0.453106      0.494508      0.395616
# EXT_BMSBS106       0.571871      0.719339      0.599158      0.740921
# INT_BMSECO102      0.505312      0.402572      0.600060      0.395162
# EXT_BMSECO102      0.584264      0.714335      0.489494      0.727525
# INT_BMSFA105       0.674887      0.542612      0.727725      0.485876
# EXT_BMSFA105       0.516311      0.741987      0.573785      0.761472
# INT_BMSFC104       0.631002      0.482647      0.757242      0.462484
# EXT_BMSFC104       0.540196      0.786387      0.512596      0.691755
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(correlation_metrics,annot = True)
plt.show()

# %% [markdown]
# ## 5. Credits and Marks Analysis

# %%
# Credits vs Marks
sns.scatterplot(data = df, x = 'CreditsEarned', y = 'TotalMarksObtained', hue = 'Remark')
plt.title('Credits Earned vs Total Marks Obtained')
plt.xlabel('Credits Earned')
plt.ylabel('Total Marks Obtained')
plt.show()

# %%
# Percentage and Credits
sns.scatterplot(data = df, x = 'CreditsEarned', y = 'Percentage', hue = 'Remark')
plt.title('Credits Earned vs Percentage')
plt.xlabel('Credits Earned')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# ## 6. Outlier Detection

# %%
from scipy import stats

df['TotalMarks_z'] = stats.zscore(df['TotalMarksObtained'])
df['Percentage_z'] = stats.zscore(df['Percentage'])
df['SGPA_z'] = stats.zscore(df['SGPA'])

# Define outliers as those with z-scores beyond ±3
outliers_total_marks = df[df['TotalMarks_z'].abs() > 3]
outliers_percentage = df[df['Percentage_z'].abs() > 3]
outliers_sgpa = df[df['SGPA_z'].abs() > 3]

print('Outliers in Total Marks Obtained:')
print(outliers_total_marks)
print('Outliers in Percentage:')
print(outliers_percentage)
print('Outliers in SGPA:')
print(outliers_sgpa)
# Out:
# Outliers in Total Marks Obtained:
#     StudentId  INT_BMSBC103  EXT_BMSBC103  INT_BMSBL107  EXT_BMSBL107  \
# 1     3735958             0             0             2             0
# 79    3736064             0             0            14             0
#
#     INT_BMSBS106  EXT_BMSBS106  INT_BMSECO102  EXT_BMSECO102  INT_BMSFA105  \
# 1              0             0             12              0             6
# 79             0             0             20              0             9
#
#     ...  Remark  Grade  TotalMarksObtained  TotalMarks  CreditsEarned  \
# 1   ...    FAIL      F                  20         700              0
# 79  ...    FAIL      F                  71         700              0
#
#    Percentage SGPA  TotalMarks_z  Percentage_z    SGPA_z
# 1        2.86  0.0     -5.926340     -5.925954 -4.699101
# 79      10.14  0.0     -5.324245     -5.324344 -4.699101
#
# [2 rows x 25 columns]
# Outliers in Percentage:
# ...
